# %%
n = 9
for i in range(n-2):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
diction = {2:['a','b','c'],
            3:['d','e','f'],
            4:['g','h','i'],
            5:['j','k','l'],
            6:['m','n','o'],
            7:['p','q','r','s'],
            8:['t','u','v'],
            9:['w','x','y','z']}

# %%
len(diction[7])
# Out:
# 4

# %%
diction[2][0]
# Out:
# 'a'

# %%
a = [1,2,3,4,5]

# %%
a.pop(5-2)
# Out:
# 4

# %%
a.append("d")
